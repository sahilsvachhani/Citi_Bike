# %%
from dotenv import load_dotenv
import os
load_dotenv()

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from datetime import datetime
import pandas as pd
from src.data_utils import load_and_process_citibike_data, transform_raw_data_into_ts_data

# Load Citi Bike data (2023)
from_year = 2023
to_year = 2023
print(f"Loading Citi Bike data from {from_year} to {to_year}")

rides = pd.DataFrame()
chunks = []
for year in range(from_year, to_year+1):
    rides_one_year = load_and_process_citibike_data(year)
    chunks.append(rides_one_year)
    break  # You can remove this break to load multiple years

rides = pd.concat(chunks, ignore_index=True)
print("✅ Citi Bike ride data loaded:", rides.shape)

# Rename columns to match expected format
rides.rename(columns={"start_station_id": "pickup_location_id", "started_at": "pickup_datetime"}, inplace=True)

# Transform to hourly time series
ts_data = transform_raw_data_into_ts_data(rides)
print("✅ Transformed to time-series format:", ts_data.shape)
ts_data.info()
# Out:
# Loading Citi Bike data from 2023 to 2023
#
# 📁 Looking for monthly zips in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202301-citibike-tripdata
# 🗂️ Reading 202301-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202301-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# ✅ Finished processing for 2023-01
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202302-citibike-tripdata
# 🗂️ Reading 202302-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# 🗂️ Reading 202302-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-02
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202303-citibike-tripdata
# 🗂️ Reading 202303-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202303-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202303-citibike-tripdata_3.csv
# ✅ Finished processing for 2023-03
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202304-citibike-tripdata
# 🗂️ Reading 202304-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# 🗂️ Reading 202304-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# 🗂️ Reading 202304-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-04
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202305-citibike-tripdata
# 🗂️ Reading 202305-citibike-tripdata_4.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# 🗂️ Reading 202305-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202305-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# 🗂️ Reading 202305-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# ✅ Finished processing for 2023-05
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202306-citibike-tripdata
# 🗂️ Reading 202306-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202306-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202306-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202306-citibike-tripdata_4.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-06
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202307-citibike-tripdata
# 🗂️ Reading 202307-citibike-tripdata_4.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202307-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202307-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202307-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-07
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202308-citibike-tripdata
# 🗂️ Reading 202308-citibike-tripdata_4.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202308-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202308-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202308-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-08
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202309-citibike-tripdata
# 🗂️ Reading 202309-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202309-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202309-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202309-citibike-tripdata_4.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-09
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202310-citibike-tripdata
# 🗂️ Reading 202310-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202310-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202310-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202310-citibike-tripdata_4.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-10
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202311-citibike-tripdata
# 🗂️ Reading 202311-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202311-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202311-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# ✅ Finished processing for 2023-11
#
# 📁 Checking for CSVs in: /Users/tejas/Desktop/Zia Final Project/data/raw/2023-citibike-tripdata/2023-citibike-tripdata/202312-citibike-tripdata
# 🗂️ Reading 202312-citibike-tripdata_2.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202312-citibike-tripdata_3.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)
# 🗂️ Reading 202312-citibike-tripdata_1.csv
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:203: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# ✅ Finished processing for 2023-12
#
# ✅ All data loaded. Total records: 316,816
# ✅ Citi Bike ride data loaded: (316816, 15)
# ✅ Transformed to time-series format: (26535, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26535 entries, 0 to 26534
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pickup_hour         26535 non-null  datetime64[ns]
#  1   pickup_location_id  26535 non-null  object
#  2   rides               26535 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 622.0+ KB
# /Users/tejas/Desktop/Zia Final Project/src/data_utils.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_station_id'] = df['start_station_id'].astype(str)

# %%
ts_data.head()
# Out:
#           pickup_hour pickup_location_id  rides
# 0 2022-12-28 11:00:00            5329.03      1
# 1 2022-12-28 12:00:00            5329.03      0
# 2 2022-12-28 13:00:00            5329.03      0
# 3 2022-12-28 14:00:00            5329.03      0
# 4 2022-12-28 15:00:00            5329.03      0

# %%
# !pip install hopsworks

# %%
import hopsworks

project = hopsworks.login()  # or hopsworks.login(api_key_value="your_api_key")
feature_store = project.get_feature_store()
# Out:
# 2025-05-10 00:14:46,330 INFO: Initializing external client
# 2025-05-10 00:14:46,330 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-05-10 00:14:47,293 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1228960

# %%
# pip install "hopsworks[python]"

# %%
# pip install confluent-kafka

# %%
from hsfs.feature import Feature

features = [
    Feature(name="pickup_hour", type="timestamp"),
    Feature(name="pickup_location_id", type="string"),
    Feature(name="rides", type="bigint"),
]

feature_group = feature_store.get_or_create_feature_group(
    name="citibike_hourly_features",
    version=1,
    description="Time-series Citi Bike rides aggregated by hour and location",
    primary_key=["pickup_location_id", "pickup_hour"],
    event_time="pickup_hour",
    features=features
)

feature_group.insert(ts_data, write_options={"wait_for_job": False})
# Out:
# Uploading Dataframe: 100.00% |██████████| Rows 26535/26535 | Elapsed Time: 00:04 | Remaining Time: 00:00
# Launching job: citibike_hourly_features_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1228960/jobs/named/citibike_hourly_features_1_offline_fg_materialization/executions
# (Job('citibike_hourly_features_1_offline_fg_materialization', 'SPARK'), None)

# %%
# Load the feature group (if not already loaded)
feature_group = feature_store.get_feature_group(
    name="citibike_hourly_features",
    version=1
)

# Read data from offline storage
ts_data_from_hopsworks = feature_group.read()

# Preview the data
ts_data_from_hopsworks.head()
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.88s)
#                 pickup_hour pickup_location_id  rides
# 0 2023-05-24 16:00:00+00:00            6140.05     42
# 1 2023-07-01 20:00:00+00:00            6948.10     12
# 2 2023-10-22 14:00:00+00:00            6948.10     38
# 3 2023-08-07 18:00:00+00:00            6140.05     57
# 4 2023-01-11 23:00:00+00:00            6948.10      0

# %%
# notebooks/create_full_feature_group.py
import sys
import os

# Add root path to sys.path (adjust if needed)
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from datetime import datetime, timedelta
import logging
import pandas as pd
import hopsworks

from src.data_utils import (
    load_and_process_citibike_data_from_local,
    transform_raw_data_into_ts_data,
)
import src.config as config
from hsfs.feature import Feature

# ─────────────────────────────────────────────────────
# Logging setup
# ─────────────────────────────────────────────────────
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s  %(levelname)s  %(message)s",
    handlers=[logging.StreamHandler(sys.stdout)]
)
logger = logging.getLogger(__name__)

# ─────────────────────────────────────────────────────
# 1. Load raw Citi Bike data (2023 only)
# ─────────────────────────────────────────────────────
logger.info("📅 Loading Citi Bike data from Jan to Dec 2023 …")
raw_rides = load_and_process_citibike_data_from_local(
    year=2023,
    months=list(range(1, 13)),
    base_path=config.LOCAL_CITIBIKE_DATA_PATH,
)
logger.info(f"✅ Loaded {len(raw_rides):,} rows of 2023 ride data.")

# ─────────────────────────────────────────────────────
# 2. Transform raw data into hourly time-series
# ─────────────────────────────────────────────────────
logger.info("🧮 Aggregating to hourly time-series format …")
ts_data = transform_raw_data_into_ts_data(raw_rides)

# ─────────────────────────────────────────────────────
# 3. Log in to Hopsworks
# ─────────────────────────────────────────────────────
logger.info("🔐 Logging in to Hopsworks …")
project = hopsworks.login(
    project=config.HOPSWORKS_PROJECT_NAME,
    api_key_value=config.HOPSWORKS_API_KEY,
)
fs = project.get_feature_store()

# ─────────────────────────────────────────────────────
# 4. Define feature group schema (fixed schema)
# ─────────────────────────────────────────────────────
fg_schema = [
    Feature("pickup_hour", "timestamp"),
    Feature("pickup_location_id", "string"),
    Feature("rides", "bigint"),  # ← FIXED: now matches Hopsworks expected type
]
# ─────────────────────────────────────────────────────
# 5. Create or update Hopsworks feature group
# ─────────────────────────────────────────────────────
logger.info("📦 Writing to Hopsworks feature group …")
hourly_fg = fs.get_or_create_feature_group(
    name="citibike_hourly_features",
    version=1,
    description="Hourly Citi Bike rides per location (2023)",
    primary_key=["pickup_hour", "pickup_location_id"],
    event_time="pickup_hour",
    online_enabled=False,
    features=fg_schema,
)

# ✅ Ensure types match the schema
ts_data["pickup_location_id"] = ts_data["pickup_location_id"].astype(str)
ts_data["rides"] = ts_data["rides"].astype("int64")  # ← FIXED: bigint = int64 in pandas

# ─────────────────────────────────────────────────────
# 6. Insert into feature store
# ─────────────────────────────────────────────────────
hourly_fg.insert(ts_data, write_options={"wait_for_job": True})
logger.info("✅ Done uploading data to Hopsworks!")
# Out:
# 2025-05-10 00:15:02,740 INFO: 📅 Loading Citi Bike data from Jan to Dec 2023 …
# 2025-05-10 00:15:03,944 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:05,305 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:06,918 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:07,980 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:09,192 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:10,752 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:12,035 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:13,325 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:15,035 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:16,685 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:18,560 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:19,818 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:21,065 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:22,622 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:24,297 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:25,680 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:26,921 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:28,246 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:29,265 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:30,666 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:32,302 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:33,994 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:35,100 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:36,320 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:37,613 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:38,973 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:40,722 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:42,338 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:43,969 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:44,935 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:46,371 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:47,677 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:48,992 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:49,684 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:50,759 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:52,153 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:53,677 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:55,272 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:56,519 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:58,134 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:15:59,545 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:00,899 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:02,476 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:04,033 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:05,739 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:07,342 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:08,921 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:10,221 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:11,558 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:12,858 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:14,437 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:15,992 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:17,533 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:18,458 WARNING: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:19,827 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:21,126 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:22,463 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:23,187 WARNING: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:24,584 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:26,129 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:27,702 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:28,901 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:30,331 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:31,684 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:33,029 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:34,046 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:35,519 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:37,053 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:38,357 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:39,859 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:41,182 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:42,295 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:43,840 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:44,456 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:45,709 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:47,251 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:47,631 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:48,861 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 00:16:49,268 INFO: ✅ Loaded 410,344 rows of 2023 ride data.
# 2025-05-10 00:16:49,268 INFO: 🧮 Aggregating to hourly time-series format …
# 2025-05-10 00:16:49,417 INFO: 🔐 Logging in to Hopsworks …
# 2025-05-10 00:16:49,418 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2025-05-10 00:16:49,422 INFO: Initializing external client
# 2025-05-10 00:16:49,423 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-05-10 00:16:50,222 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1228960
# 2025-05-10 00:16:50,961 INFO: 📦 Writing to Hopsworks feature group …
# Uploading Dataframe: 100.00% |██████████| Rows 26535/26535 | Elapsed Time: 00:03 | Remaining Time: 00:00
# 2025-05-10 00:16:58,079 WARNING: UserWarning: Materialization job is already running, aborting new execution.Please wait for the current execution to finish before triggering a new one.You can check the status of the current execution using `fg.materialization_job.get_state()`.or `fg.materialization_job.get_final_state()` or check it out in the Hopsworks UI.at https://c.app.hopsworks.ai:443/p/1228960/jobs/named/citibike_hourly_features_1_offline_fg_materialization.
# Use fg.materialization_job.run(args=-op offline_fg_materialization -path hdfs:///Projects/sahilsvachhani/Resources/jobs/citibike_hourly_features_1_offline_fg_materialization/config_1746843211055) to trigger the materialization job again.
#
# 2025-05-10 00:16:58,080 INFO: ✅ Done uploading data to Hopsworks!
