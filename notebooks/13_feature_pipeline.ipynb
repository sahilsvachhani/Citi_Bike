# %%
# Step 1: Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import hopsworks
from hsfs.feature import Feature

from src.data_utils import load_and_process_citibike_data_from_local, transform_raw_data_into_ts_data
import src.config as config

# %%
# Step 2: Load Data from Local
print("📂 Loading Citi Bike data (2023)...")
data = load_and_process_citibike_data_from_local(
    year=2023,
    months=[1,2,3,4,5,6],
    base_path=config.LOCAL_CITIBIKE_DATA_PATH
)
# Out:
# 📂 Loading Citi Bike data (2023)...
# 2025-05-10 05:52:58,750 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:00,057 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:01,471 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:02,458 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:03,552 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:04,960 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:06,158 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:07,331 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:08,825 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:10,331 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:12,087 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:13,268 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:14,455 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:15,917 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:17,471 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:18,741 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:19,899 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:21,106 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:22,046 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:23,349 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:24,892 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:26,490 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:27,509 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:28,650 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:29,839 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:31,066 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:32,697 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:34,426 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:36,037 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:36,925 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:38,274 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:39,480 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:40,688 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 05:53:41,324 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
print("✅ Loaded data shape:", data.shape)
display(data.head())
# Out:
# ✅ Loaded data shape: (157285, 14)
#             ride_id  rideable_type         pickup_datetime  \
# 0  A46D077151843D7B   classic_bike 2023-01-16 10:39:54.386
# 1  233875BAED2E02D0   classic_bike 2023-01-12 16:55:30.755
# 2  8DD222EA1A1B0BC9  electric_bike 2023-01-08 19:32:25.647
# 3  58976A4F584F8D28   classic_bike 2023-01-27 20:01:52.897
# 4  FDD4C1E89A26727C   classic_bike 2023-01-13 18:02:38.160
#
#                   ended_at     start_station_name pickup_location_id  \
# 0  2023-01-16 10:45:18.005  West St & Chambers St            5329.03
# 1  2023-01-12 17:04:03.688  West St & Chambers St            5329.03
# 2  2023-01-08 19:42:00.382  West St & Chambers St            5329.03
# 3  2023-01-27 20:08:58.118  West St & Chambers St            5329.03
# 4  2023-01-13 18:11:22.139  West St & Chambers St            5329.03
#
#   end_station_name end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 0   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
# 1   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
# 2   West Thames St        5114.06  40.717618 -74.013071  40.708347 -74.017134
# 3   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
# 4   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
#
#   member_casual                     source_file
# 0        member  202301-citibike-tripdata_1.csv
# 1        member  202301-citibike-tripdata_1.csv
# 2        member  202301-citibike-tripdata_1.csv
# 3        member  202301-citibike-tripdata_1.csv
# 4        member  202301-citibike-tripdata_1.csv

# %%
# Step 3: Preprocess Data
data["pickup_datetime"] = pd.to_datetime(data["pickup_datetime"], errors="coerce")
data = data.dropna(subset=["pickup_datetime", "pickup_location_id"])
data["pickup_location_id"] = data["pickup_location_id"].astype(str)
data["pickup_hour"] = data["pickup_datetime"].dt.floor("h")

# %%
# Step 4: Transform into Hourly Time-Series
ts_data = transform_raw_data_into_ts_data(data)
print("✅ Transformed time-series shape:", ts_data.shape)
display(ts_data.head())
# Out:
# ✅ Transformed time-series shape: (13287, 3)
#           pickup_hour pickup_location_id  rides
# 0 2022-12-28 11:00:00            5329.03      2
# 1 2022-12-28 12:00:00            5329.03      0
# 2 2022-12-28 13:00:00            5329.03      0
# 3 2022-12-28 14:00:00            5329.03      0
# 4 2022-12-28 15:00:00            5329.03      0

# %%
# Step 5: Check Aggregation Info
print("📅 Date range:", ts_data.pickup_hour.min(), "→", ts_data.pickup_hour.max())
print("🧠 Nulls present:")
display(ts_data.isnull().sum())
# Out:
# 📅 Date range: 2022-12-28 11:00:00 → 2023-06-30 23:00:00
# 🧠 Nulls present:
# pickup_hour           0
# pickup_location_id    0
# rides                 0
# dtype: int64

# %%
# Step 6: Visualize Time-Series
plt.figure(figsize=(12, 5))
for location_id in ts_data.pickup_location_id.unique():
    subset = ts_data[ts_data.pickup_location_id == location_id]
    plt.plot(subset.pickup_hour, subset.rides, label=f"Location {location_id}")
plt.legend()
plt.title("📈 Hourly Ride Counts for Top Stations")
plt.xlabel("Time")
plt.ylabel("Rides")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 2025-05-10 05:53:52,057 WARNING: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#
# 2025-05-10 05:53:52,084 WARNING: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.

# %%
csv_path = config.TRANSFORMED_DATA_DIR / "jan_jun_2023_ts_data.csv"
ts_data.to_csv(csv_path, index=False)
print(f"💾 Saved to: {csv_path}")
# Out:
# 💾 Saved to: /Users/tejas/Desktop/Zia Final Project/data/transformed/jan_jun_2023_ts_data.csv

# %%
# Step 8: Connect to Hopsworks and Register Feature Group
print("🔐 Logging in to Hopsworks ...")
project = hopsworks.login(
    project=config.HOPSWORKS_PROJECT_NAME,
    api_key_value=config.HOPSWORKS_API_KEY
)
fs = project.get_feature_store()
# Out:
# 🔐 Logging in to Hopsworks ...
# 2025-05-10 05:53:54,401 INFO: Initializing external client
# 2025-05-10 05:53:54,402 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-05-10 05:53:55,364 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1228960

# %%
# Define schema and feature group
schema = [
    Feature("pickup_hour", "timestamp"),
    Feature("pickup_location_id", "string"),
    Feature("rides", "int")
]

fg = fs.get_or_create_feature_group(
    name=config.FEATURE_GROUP_NAME,
    version=config.FEATURE_GROUP_VERSION,
    description="Hourly Citi Bike rides (March 2023)",
    primary_key=["pickup_hour", "pickup_location_id"],
    event_time="pickup_hour",
    online_enabled=False,
    features=schema
)

# %%
# Cast dtypes and insert
print("📤 Writing to Hopsworks...")
ts_data["pickup_location_id"] = ts_data["pickup_location_id"].astype(str)
ts_data["rides"] = ts_data["rides"].astype("int64")
fg.insert(ts_data, write_options={"wait_for_job": True})
print("✅ Successfully registered with Hopsworks")
# Out:
# 📤 Writing to Hopsworks...
# Uploading Dataframe: 100.00% |██████████| Rows 13287/13287 | Elapsed Time: 00:02 | Remaining Time: 00:00
# Launching job: citibike_hourly_features_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1228960/jobs/named/citibike_hourly_features_1_offline_fg_materialization/executions
# 2025-05-10 05:57:26,291 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-05-10 05:57:29,400 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-05-10 05:59:24,593 INFO: Waiting for execution to finish. Current state: SUCCEEDING. Final status: UNDEFINED
# 2025-05-10 05:59:27,709 INFO: Waiting for execution to finish. Current state: FINISHED. Final status: SUCCEEDED
# 2025-05-10 05:59:27,980 INFO: Waiting for log aggregation to finish.
# 2025-05-10 05:59:27,981 INFO: Execution finished successfully.
# ✅ Successfully registered with Hopsworks
